# %% [markdown]
# # **MNIST 필기체 숫자 인식 -> CNN**

# %% [markdown]
# 1. Data load

# %%
import tensorflow as tf
import matplotlib.pyplot as plt


(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

print(train_images.shape)  # (데이터 개수, 세로, 가로)
print(test_images.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# 2. Data Preprocessing

# %%
# Data reshaping
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# %%
# Normalization
train_images = train_images.astype("float32") / 255.0
test_images = test_images.astype("float32") / 255.0

# %% [markdown]
# 3. Model Building

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28, 28, 1)),

    # Data Augumentation (데이터 증강) =======
    tf.keras.layers.RandomRotation(0.08),
    tf.keras.layers.RandomTranslation(0.08, 0.08),
    tf.keras.layers.RandomZoom(0.05),
    # ======================(교재 p. 335)=====


    tf.keras.layers.Conv2D(32, (3, 3), activation="relu"),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(64, (3, 3), activation="relu"),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(64, (3, 3), activation="relu"),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax"),
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_rotation                 │ (None, 28, 28, 1)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_translation              │ (None, 28, 28, 1)      │             0 │
# │ (RandomTranslation)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 93,322 (364.54 KB)
#  Trainable params: 93,322 (364.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilation
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %% [markdown]
# 4. Model fit

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=7,
    restore_best_weights=True,
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6
)

history = model.fit(
    train_images,
    train_labels,
    epochs=50,
    batch_size=64,
    validation_split=0.1,
    callbacks=[early_stopping, reduce_lr],
)
# Out:
# Epoch 1/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 58s 66ms/step - accuracy: 0.8724 - loss: 0.4021 - val_accuracy: 0.9838 - val_loss: 0.0614 - learning_rate: 0.0010
# Epoch 2/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 53s 63ms/step - accuracy: 0.9581 - loss: 0.1348 - val_accuracy: 0.9853 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 3/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 57s 68ms/step - accuracy: 0.9685 - loss: 0.1016 - val_accuracy: 0.9872 - val_loss: 0.0460 - learning_rate: 0.0010
# Epoch 4/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 56s 67ms/step - accuracy: 0.9742 - loss: 0.0841 - val_accuracy: 0.9653 - val_loss: 0.1067 - learning_rate: 0.0010
# Epoch 5/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 51s 61ms/step - accuracy: 0.9767 - loss: 0.0724 - val_accuracy: 0.9867 - val_loss: 0.0478 - learning_rate: 0.0010
# Epoch 6/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 81s 60ms/step - accuracy: 0.9786 - loss: 0.0677 - val_accuracy: 0.9907 - val_loss: 0.0352 - learning_rate: 0.0010
# Epoch 7/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 53s 63ms/step - accuracy: 0.9811 - loss: 0.0615 - val_accuracy: 0.9877 - val_loss: 0.0486 - learning_rate: 0.0010
# Epoch 8/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 52s 62ms/step - accuracy: 0.9826 - loss: 0.0557 - val_accuracy: 0.9868 - val_loss: 0.0412 - learning_rate: 0.0010
# Epoch 9/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 55s 65ms/step - accuracy: 0.9831 - loss: 0.0523 - val_accuracy: 0.9893 - val_loss: 0.0456 - learning_rate: 0.0010
# Epoch 10/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 53s 63ms/step - accuracy: 0.9881 - loss: 0.0387 - val_accuracy: 0.9900 - val_loss: 0.0410 - learning_rate: 5.0000e-04
# Epoch 11/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 54s 64ms/step - accuracy: 0.9882 - loss: 0.0361 - val_accuracy: 0.9907 - val_loss: 0.0313 - learning_rate: 5.0000e-04
# Epoch 12/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 54s 63ms/step - accuracy: 0.9883 - loss: 0.0361 - val_accuracy: 0.9918 - val_loss: 0.0309 - learning_rate: 5.0000e-04
# Epoch 13/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 52s 61ms/step - accuracy: 0.9890 - loss: 0.0343 - val_accuracy: 0.9930 - val_loss: 0.0323 - learning_rate: 5.0000e-04
# Epoch 14/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 81s 61ms/step - accuracy: 0.9894 - loss: 0.0344 - val_accuracy: 0.9925 - val_loss: 0.0310 - learning_rate: 5.0000e-04
# Epoch 15/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 52s 62ms/step - accuracy: 0.9895 - loss: 0.0323 - val_accuracy: 0.9928 - val_loss: 0.0318 - learning_rate: 5.0000e-04
# Epoch 16/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 54s 64ms/step - accuracy: 0.9919 - loss: 0.0264 - val_accuracy: 0.9920 - val_loss: 0.0300 - learning_rate: 2.5000e-04
# Epoch 17/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 83s 65ms/step - accuracy: 0.9918 - loss: 0.0259 - val_accuracy: 0.9922 - val_loss: 0.0294 - learning_rate: 2.5000e-04
# Epoch 18/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 53s 63ms/step - accuracy: 0.9912 - loss: 0.0264 - val_accuracy: 0.9927 - val_loss: 0.0297 - learning_rate: 2.5000e-04
# Epoch 19/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 54s 64ms/step - accuracy: 0.9920 - loss: 0.0249 - val_accuracy: 0.9923 - val_loss: 0.0306 - learning_rate: 2.5000e-04
# Epoch 20/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 54s 63ms/step - accuracy: 0.9923 - loss: 0.0253 - val_accuracy: 0.9913 - val_loss: 0.0302 - learning_rate: 2.5000e-04
# Epoch 21/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 51s 60ms/step - accuracy: 0.9927 - loss: 0.0227 - val_accuracy: 0.9923 - val_loss: 0.0291 - learning_rate: 1.2500e-04
# Epoch 22/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 54s 63ms/step - accuracy: 0.9935 - loss: 0.0206 - val_accuracy: 0.9928 - val_loss: 0.0269 - learning_rate: 1.2500e-04
# Epoch 23/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 52s 62ms/step - accuracy: 0.9936 - loss: 0.0200 - val_accuracy: 0.9928 - val_loss: 0.0291 - learning_rate: 1.2500e-04
# Epoch 24/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 55s 65ms/step - accuracy: 0.9932 - loss: 0.0214 - val_accuracy: 0.9933 - val_loss: 0.0288 - learning_rate: 1.2500e-04
# Epoch 25/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 53s 62ms/step - accuracy: 0.9937 - loss: 0.0198 - val_accuracy: 0.9918 - val_loss: 0.0319 - learning_rate: 1.2500e-04
# Epoch 26/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 81s 62ms/step - accuracy: 0.9936 - loss: 0.0194 - val_accuracy: 0.9930 - val_loss: 0.0272 - learning_rate: 6.2500e-05
# Epoch 27/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 54s 64ms/step - accuracy: 0.9943 - loss: 0.0175 - val_accuracy: 0.9932 - val_loss: 0.0287 - learning_rate: 6.2500e-05
# Epoch 28/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 53s 63ms/step - accuracy: 0.9945 - loss: 0.0178 - val_accuracy: 0.9928 - val_loss: 0.0282 - learning_rate: 6.2500e-05
# Epoch 29/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 80s 60ms/step - accuracy: 0.9946 - loss: 0.0174 - val_accuracy: 0.9925 - val_loss: 0.0288 - learning_rate: 3.1250e-05

# %% [markdown]
# 5. Model Test & Evaluation

# %%
test_loss, test_accuracy = model.evaluate(test_images, test_labels)

print("Test accuracy:", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9941 - loss: 0.0199
# Test accuracy: 0.9940999746322632

# %% [markdown]
# 6. Result Visualization

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
