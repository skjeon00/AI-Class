# %% [markdown]
# # **Linear Regression**
# csv : breast_cancer.csv

# %% [markdown]
# - google drive mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - CSV 파일 읽기

# %%
import pandas as pd
import numpy as np

path = '/content/drive/MyDrive/Colab Notebooks/breast_cancer.csv'  # 읽으려는 CSV 파일 경로 복사 및 붙여놓기

df = pd.read_csv(path, index_col=0)   # CSV 파일을 DataFrame으로 읽기

df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# - 정답/입력데이터 설정

# %%
df2=df.drop('label',axis=1)
df.head()

# y값(정답) 지정
y=df2['worst compactness']
y.value_counts()
y

# X값(데이터) 지정 : 세로축을 기준으로 worst compactness 한 줄을 제외한 나머지 데이터
X=df2.drop('worst compactness',axis=1)
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  fractal dimension error  worst radius  \
# ...

# %% [markdown]
# - model import + train/test 설정

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

# %% [markdown]
# - Linear Regression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(ly_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ly_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 0.0004971870077830486
# 평균제곱근오차 0.0004971870077830486
# 평균제곱근오차 0.0004971870077830486
# <>:13: SyntaxWarning: invalid decimal literal
# <>:13: SyntaxWarning: invalid decimal literal
# /tmp/ipykernel_294/2036977504.py:13: SyntaxWarning: invalid decimal literal
#   sum_square_error = sum((a - p) ** 2for a, p in zip(actual, predicted))
